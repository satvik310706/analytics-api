# %%
path = "/api/res/12"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/res/12'

# %%
import requests
data = {'lover':"navya"}
response = requests.put(endpoint, json=data)
response.json()
# Out:
# {'satvik': 'navya'}
