# %%
path = "/api/res/13"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/res/13'

# %%
import requests
response = requests.get(endpoint)
response.json()
# Out:
# {'id': 13}
